# %% [markdown]
# # Generative AI with LangChain

# %% [markdown]
# ## Load dotenv

# %%
from dotenv import load_dotenv
from google import genai
from pathlib import Path

env_path = Path('.').resolve().parent / '.env'
#print(env_path)
load_dotenv(dotenv_path=env_path, override=True)
google_client = genai.Client()
# Out:
# Both GOOGLE_API_KEY and GEMINI_API_KEY are set. Using GOOGLE_API_KEY.

# %%
import os

REPLICATE_API_TOKEN = os.getenv("REPLICATE_API_TOKEN")

# %%
import os

GEMINI_API_KEY = os.getenv("GEMINI_API_KEY")

# %%
GOOGLE_API_KEY = os.getenv("GOOGLE_API_KEY")

# %% [markdown]
# ## Simple Examples

# %%
def generate(adjective: str, topic: str, language: str) -> str:
    prompt = f"""
    Tell me a {adjective} joke about {topic} in {language}.
    """

    print(f"{prompt}\n\n---\n")

    response = google_client.models.generate_content(
        model="gemini-2.5-flash",
        contents=prompt
    )

    return response.text

answer = generate("funny", "Police", "Chinese")
print(answer)
# Out:
#     Tell me a funny joke about Police in Chinese.
#
#
# ---
#
# 好的，这是一个关于警察的幽默小段子：
#
# ---
#
# 一个警察在山上巡逻，看到一个人正把手伸进老虎的嘴里。
# 警察大吃一惊，赶紧大喊：“喂！你没看到旁边牌子上写着什么吗？‘当心老虎’！”
# 那人慢悠悠地把手抽出来，淡定地说：“没关系，警官。我不是在‘当心’它，我是在教它唱歌呢！”
#
# ---
#
# **Pinyin:**
# Yī gè jǐngchá zài shānshàng xúnluó, kàn dào yī gè rén zhèng bǎ shǒu shēn jìn lǎohǔ de zuǐ lǐ.
# Jǐngchá dàchīyījīng, gǎnjǐn dàhǎn: "Wèi! Nǐ méi kàn dào pángbiān páizi shàng xiězhe shénme ma? 'Dāngxīn lǎohǔ'!"
# Nà rén màn yōuyōu de bǎ shǒu chōu chūlái, dàndìng de shuō: "Méi guānxi, jǐngguān. Wǒ búshì zài 'dāngxīn' tā, wǒ shì zài jiào tā chànggē ne!"
#
# **English Translation:**
# A police officer was patrolling in the mountains and saw a man putting his hand into a tiger's mouth.
# The officer was shocked and quickly shouted, "Hey! Didn't you see what's written on the sign next to you? 'Beware of Tigers'!"
# The man slowly pulled his hand out and calmly said, "No worries, officer. I'm not 'bewaring' it; I'm teaching it to sing!"
#
# ...

# %%
answer = generate("funny", "Government", "Chinese")
print(answer)
# Out:
#     Tell me a funny joke about Government in Chinese.
#
#
# ---
#
# 好的，这是一个关于政府的幽默段子：
#
# **中文 (Chinese):**
#
# 问：换一个灯泡需要多少个政府工作人员？
#
# 答：一个都不需要！他们只会成立一个委员会，研究灯泡为什么坏了，应该用什么灯泡，以及更换灯泡的必要性。
#
# **拼音 (Pinyin):**
#
# Wèn: Huàn yīgè dēngpào xūyào duōshǎo gè zhèngfǔ gōngzuò rényuán?
#
# Dá: Yīgè dōu bù xūyào! Tāmen zhǐ huì chénglì yīgè wěiyuánhuì, yánjiū dēngpào wèi shénme huàile, yīnggāi yòng shénme dēngpào, yǐjí gēnghuàn dēngpào de bìyào xìng.
#
# **英文翻译 (English Translation):**
#
# Q: How many government employees does it take to change a lightbulb?
#
# A: None! They'll just form a committee to study why the lightbulb broke, what kind of lightbulb should be used, and the necessity of changing it.

# %%
answer = generate("funny", "Government", "English")
print(answer)
# Out:
#     Tell me a funny joke about Government in English.
#
#
# ---
#
# Here's one for you:
#
# "How many government employees does it take to change a lightbulb?"
# "That's easy: three. One to screw it in, and two to write the environmental impact report."

# %% [markdown]
# ## Working with Chat Models

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.messages import HumanMessage

# Initialize the model
llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash")

# Invoke the model
response = llm.invoke("Hello, how are you?")
print(response.content)
# Out:
# Both GOOGLE_API_KEY and GEMINI_API_KEY are set. Using GOOGLE_API_KEY.
# Hello! I'm doing well, thank you for asking.
#
# How are you doing today? And is there anything I can help you with?

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.messages import SystemMessage, HumanMessage

# Initialize the model
llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash")

messages = [SystemMessage(content="You are a helpful programming assistant."), 
            HumanMessage(content="Write a Python function to calculate factorial of a number.")]

response = llm.invoke(messages)

print(response.content)
# Out:
# Both GOOGLE_API_KEY and GEMINI_API_KEY are set. Using GOOGLE_API_KEY.
# You can calculate the factorial of a number in Python using a few different methods:
#
# 1.  **Iterative Method** (using a loop)
# 2.  **Recursive Method** (calling the function itself)
# 3.  **Using `math.factorial()`** (built-in function for efficiency)
#
# Let's look at implementations for the first two, and then mention the built-in one.
#
# ---
#
# ### 1. Iterative Method (using a `for` loop)
#
# This is generally the most straightforward and often preferred for performance reasons, especially for larger numbers, as it avoids the overhead of recursive calls.
#
# ```python
# def factorial_iterative(n):
#     """
#     Calculates the factorial of a non-negative integer using an iterative approach.
#
#     Args:
#         n (int): The non-negative integer for which to calculate the factorial.
#
#     Returns:
#         int: The factorial of n.
#
#     Raises:
#         TypeError: If n is not an integer.
# ...

# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate

template = ChatPromptTemplate.from_messages([
    ("system", "You are a problem-solving assistant."),
    ("user", "{problem}")
]) 

chat = ChatOpenAI(model="gpt-5.2", 
                  temperature=0.1,
                  reasoning_effort="high"
                )

chain = template | chat
response = chain.invoke({"problem": "Design a algorithm find a shortest path in google maps? And explain the algorithm in detail."})

print(response.content)
# Out:
# Below is a practical “Google‑Maps-like” shortest‑path algorithm design. Google’s exact implementation is proprietary, but large-scale map routing systems typically combine:
#
# - **Graph shortest-path (Dijkstra/A\*)**
# - **Heavily optimized preprocessing (Contraction Hierarchies / Multi-Level graphs)**
# - **Time-dependent edge weights (traffic, closures)**
# - **Turn costs/restrictions and preferences (avoid tolls, highways, etc.)**
#
# I’ll describe a concrete algorithm that you can implement.
#
# ---
#
# ## 1) Model the road network as a directed graph
#
# ### Graph
# - **Vertices (nodes)**: intersections, road endpoints, some midpoints for complex geometry.
# - **Edges**: directed road segments you can travel (one-way streets become one directed edge; two-way roads become two edges).
#
# Each edge stores:
# - `length_m`
# - `speed_limit` or typical speed
# - `road_class` (highway/arterial/local)
# - `toll`, `ferry`, `unpaved`, etc.
# ...

# %% [markdown]
# ## Local Model

# %%
from langchain_ollama import ChatOllama
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser

# Initialize Ollama with your chosen model
local_llm = ChatOllama(
    model="deepseek-r1:1.5b",
    temperature=0,
)

# Create an LCEL chain using the local model
prompt = PromptTemplate.from_template("Explain {concept} in simple terms")
local_chain = prompt | local_llm | StrOutputParser()

# Use the chain with your local model
results = local_chain.invoke({"concept": "polymer entanglements"})
print(results)
# Out:
# Polymer entanglements are a phenomenon observed in glassy polymers and other solutions where the repeating chains within the polymer tend to interlock with each other. This occurs because the molecules in the polymer have specific structures that prevent them from moving freely past one another. When sheared (stretched) or compressed, these entangled chains restrict movement, altering the polymer's flow properties. Examples include certain plastics and gels, where entanglement affects their behavior under stress.

# %% [markdown]
# ## Multimodel AI application

# %% [markdown]
# ### Text to Image (using DALL-E through OpenAI)

# %%
from langchain_community.utilities.dalle_image_generator import DallEAPIWrapper

dalle = DallEAPIWrapper(
    model="dall-e-3",
    size="1024x1024",
    quality="hd"
)

# Generate an image
image_url = dalle.run("A detailed technical diagram of an AI agent")

# display the image in the notebook
from IPython.display import Image, display
display(Image(url=image_url))
# Out:
# <img src="https://oaidalleapiprodscus.blob.core.windows.net/private/org-TAf8ApJhZxgNYGFWssrLynBc/user-mZFA2j5MvhppxNrIS1Yhp31H/img-UEXeyF84r4obgMgFMRtyyd4j.png?st=2026-05-06T00%3A22%3A21Z&se=2026-05-06T02%3A22%3A21Z&sp=r&sv=2026-02-06&sr=b&rscd=inline&rsct=image/png&skoid=8eb2c87c-0531-4dab-acb3-b5e2adddce6c&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2026-05-05T17%3A44%3A29Z&ske=2026-05-06T17%3A44%3A29Z&sks=b&skv=2026-02-06&sig=JVxFpeu4copfOBQc/MGNI1vrBRHLnaAX2gDzZBx2Jqg%3D"/>

# %%
from langchain_community.utilities.dalle_image_generator import DallEAPIWrapper

dalle = DallEAPIWrapper(
    model="dall-e-3",
    size="1024x1024",
    quality="hd"
)

# Generate an image
image_url = dalle.run("A detailed technical diagram of an AI agent which look like a human")

# display the image in the notebook
from IPython.display import Image, display
display(Image(url=image_url))
# Out:
# <img src="https://oaidalleapiprodscus.blob.core.windows.net/private/org-TAf8ApJhZxgNYGFWssrLynBc/user-mZFA2j5MvhppxNrIS1Yhp31H/img-SYzk4nbcfufuj8L3kexP16uS.png?st=2026-05-06T00%3A24%3A30Z&se=2026-05-06T02%3A24%3A30Z&sp=r&sv=2026-02-06&sr=b&rscd=inline&rsct=image/png&skoid=8eb2c87c-0531-4dab-acb3-b5e2adddce6c&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2026-05-05T15%3A09%3A30Z&ske=2026-05-06T15%3A09%3A30Z&sks=b&skv=2026-02-06&sig=Tv5ONzpejsfD1y8pCY7fzjFrDGurEMOuFboI75v3r64%3D"/>

# %%
from langchain_community.utilities.dalle_image_generator import DallEAPIWrapper

dalle = DallEAPIWrapper(
    model="dall-e-3",
    size="1024x1024",
    quality="hd"
)

# Generate an image
image_url = dalle.run("A detailed technical diagram of an AI agent which look like Scarlett Johansson in the movie <Ghost in the Shell>. ")

# display the image in the notebook
from IPython.display import Image, display
display(Image(url=image_url))
# Out:
# <img src="https://oaidalleapiprodscus.blob.core.windows.net/private/org-TAf8ApJhZxgNYGFWssrLynBc/user-mZFA2j5MvhppxNrIS1Yhp31H/img-9ZiSNGZVtCgdwIx3Nqkg05BH.png?st=2026-05-06T00%3A28%3A27Z&se=2026-05-06T02%3A28%3A27Z&sp=r&sv=2026-02-06&sr=b&rscd=inline&rsct=image/png&skoid=32836cae-d25f-4fe9-827b-1c8c59c442cc&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2026-05-05T16%3A09%3A48Z&ske=2026-05-06T16%3A09%3A48Z&sks=b&skv=2026-02-06&sig=BpWChN6FbylbPnZZCZ6j2KTt3Eyd6/%2Bo9nMpjwnKeUw%3D"/>

# %%
# save the image locally

import requests

response = requests.get(image_url)

with open("generated_image.png", "wb") as f:
    f.write(response.content)

# %% [markdown]
# ### Using Stable Diffusion

# %%
import os
from langchain_community.llms import Replicate

text2image = Replicate(
    model="stability-ai/stable-diffusion-3.5-large", 
    model_kwargs={
        "prompt": "A detailed technical diagram of an AI agent that looks like Scarlett Johansson in the movie <Ghost in the Shell>. ",
        "prompt_strength": 0.85,
        "cfg": 4.5,
        "steps": 40,
        "aspect_ratio": "1:1",
        "output_format": "webp",
        "output_quality": 90
    }
)

# Generate an image
image_url2 = text2image.invoke("Generate an Image")

# display the image in the notebook
from IPython.display import Image, display
display(Image(url=image_url2))
# Out:
# <img src="https://replicate.delivery/xezq/lV0aZ6pxpb55LB9BR6F9xyVUeyp8GafgyxRgwP0h8mzqPGiWA/tmp9pv57htw.webp"/>

# %%
import os
from langchain_community.llms import Replicate

text2image = Replicate(
    model="stability-ai/stable-diffusion-3.5-large", 
    model_kwargs={
        "prompt": "A detailed technical diagram of an AI agent. ",
        "prompt_strength": 0.85,
        "cfg": 4.5,
        "steps": 40,
        "aspect_ratio": "1:1",
        "output_format": "webp",
        "output_quality": 90
    }
)

# Generate an image
image_url2 = text2image.invoke("Generate an Image")

# display the image in the notebook
from IPython.display import Image, display
display(Image(url=image_url2))
# Out:
# <img src="https://replicate.delivery/xezq/eKB7x9f07ttvXkmjCnwDNZhyPht2ayvaeOwVz9Tb91UoWMEtA/tmp5usnu9u5.webp"/>

# %%
import os
from langchain_community.llms import Replicate

text2image = Replicate(
    model="stability-ai/stable-diffusion-3.5-large", 
    model_kwargs={
        "prompt": "A detailed technical diagram of an AI agent that looks like Scarlett Johansson in the movie <Ghost in the Shell>. ",
        "prompt_strength": 0.85,
        "cfg": 4.5,
        "steps": 40,
        "aspect_ratio": "1:1",
        "output_format": "webp",
        "output_quality": 90
    }
)

# Generate an image
image_url2 = text2image.invoke("Generate an Image")

# display the image in the notebook
from IPython.display import Image, display
display(Image(url=image_url2))
# Out:
# <img src="https://replicate.delivery/xezq/M9BmMcsT90pGC9O44MZwFEyCWVQW2n2HCdkkpjY4segNUDRLA/tmpjbuhq788.webp"/>

# %%
# save the image locally

import requests

response = requests.get(image_url2)

with open("generated_image2.png", "wb") as f:
    f.write(response.content)

# %% [markdown]
# ### Image Understanding

# %%
import base64
from langchain_openai import ChatOpenAI
from langchain_core.messages import HumanMessage

# 1. Initialize a multimodal model
model = ChatOpenAI(model="gpt-4o")

# 2. Helper to encode local image to Base64
def encode_image(image_path):
    with open(image_path, "rb") as image_file:
        return base64.b64encode(image_file.read()).decode('utf-8')

image_data = encode_image("generated_image.png")

# 3. Create a message with multiple content types
message = HumanMessage(
    content=[
        {"type": "text", "text": "What is depicted in this technical diagram?"},
        {
            "type": "image_url",
            "image_url": {"url": f"data:image/png;base64,{image_data}"},
        },
    ]
)

# 4. Invoke the model
response = model.invoke([message])
print(response.content)
# Out:
# This technical diagram depicts a humanoid AI agent or robot. It features detailed mechanical and anatomical illustrations showcasing various components and systems within the robotic structure. The diagram includes annotations, but the text appears to be nonsensical or placeholder, suggesting it is a conceptual or artistic representation. The diagram provides views from different angles to illustrate the intricate design of the AI agent.

# %%
import base64
from langchain_openai import ChatOpenAI
from langchain_core.messages import HumanMessage

# 1. Initialize a multimodal model
model = ChatOpenAI(model="gpt-4o")

# 2. Helper to encode local image to Base64
def encode_image(image_path):
    with open(image_path, "rb") as image_file:
        return base64.b64encode(image_file.read()).decode('utf-8')

image_data = encode_image("generated_image2.png")

# 3. Create a message with multiple content types
message = HumanMessage(
    content=[
        {"type": "text", "text": "What is depicted in this technical diagram?"},
        {
            "type": "image_url",
            "image_url": {"url": f"data:image/png;base64,{image_data}"},
        },
    ]
)

# 4. Invoke the model
response = model.invoke([message])
print(response.content)
# Out:
# This image depicts a futuristic and detailed illustration of a humanoid robot's head and shoulders. The robot is designed with intricate circuitry and mechanical components, showcasing advanced technology. The head features electronic interfaces, wiring, and glowing elements, creating a sci-fi aesthetic. The background includes digital screens with graphical elements, enhancing the high-tech theme.

# %%
import base64
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.messages import HumanMessage

# 1. Initialize a multimodal model
model = ChatGoogleGenerativeAI(
    model="gemini-3.1-pro-preview",
    temperature=0.1,  # Gemini 3.0+ defaults to 1.0
    max_tokens=None,
    timeout=None,
    max_retries=2,
    # other params...
)

# 2. Helper to encode local image to Base64
def encode_image(image_path):
    with open(image_path, "rb") as image_file:
        return base64.b64encode(image_file.read()).decode('utf-8')

image_data = encode_image("generated_image2.png")

# 3. Create a message with multiple content types
message = HumanMessage(
    content=[
        {"type": "text", "text": "What is depicted in this technical diagram?"},
        {
            "type": "image_url",
            "image_url": {"url": f"data:image/png;base64,{image_data}"},
        },
    ]
)

# 4. Invoke the model
response = model.invoke([message])
print(response.content)
# Out:
# Both GOOGLE_API_KEY and GEMINI_API_KEY are set. Using GOOGLE_API_KEY.
# ...
